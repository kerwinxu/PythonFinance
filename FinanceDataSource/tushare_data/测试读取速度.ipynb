# %% [markdown]
# # 读取所有的股票

# %%
import tushare

# %%
_all_stock=tushare.get_stock_basics()

# %%
_all_stock
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 002931    N锋龙     汽车配件   浙江    33.09         0.22    0.89     33967.37
# 000862   银星能源     新型电力   宁夏     0.00         5.01    7.06    917883.00
# 000505   京粮控股       食品   海南    44.51         3.60    6.86    474742.19
# 002323    雅百特     建筑施工   江苏    23.11         3.21    7.46    254936.59
# 002076  雪 莱 特     家用电器   广东    80.25         4.72    7.30    221171.66
# 002775   文科园林     建筑施工   深圳    18.59         1.22    2.47    275576.50
# 002930   宏川智慧     仓储物流   广东    47.25         0.61    2.43    187270.80
# 603718   海利生物     生物制药   上海    58.81         3.05    6.44    158691.55
# 603838   四通股份       陶瓷   广东    62.94         0.97    2.67     81570.74
# 300637   扬帆新材     化工原料   浙江    43.61         0.30    1.23     66780.71
# 002693   双成药业     化学制药   海南     0.00         4.03    4.05    134617.66
# 002813   路畅科技     汽车配件   深圳   257.96         0.30    1.20    134949.38
# ...

# %%
_all_stock.index # 这个就是所有的股票的代码了
# Out:
# Index(['002931', '000862', '000505', '002323', '002076', '002775', '002930',
#        '603718', '603838', '300637',
#        ...
#        '600806', '600432', '300743', '300742', '000950', '000629', '000511',
#        '603897', '603876', '603773'],
#       dtype='object', name='code', length=3513)

# %% [markdown]
# # 测试从hdf5类库里的API的读取速度

# %%
import tushare_data

# %%
def f1():
    """测试递归读取每一个"""
    for _stock in _all_stock.index:
        tushare_data.stone.select(tushare_data.str_report,'code="{}"'.format(_stock))
# %time f1()

# %% [markdown]
# # 测试pandas的读取速度

# %%
# 先全部读取到pandas中，然后用pandas来读取相关信息的
# %time _data=tushare_data.stone.select(tushare_data.str_report)
# Out:
# Wall time: 971 ms

# %%
_data.keys()
# Out:
# Index(['code', 'name', 'eps', 'eps_yoy', 'bvps', 'roe', 'epcf', 'net_profits',
#        'profits_yoy', 'distrib', 'report_date', 'year_quarter'],
#       dtype='object')

# %%
def f3():
    for _stock in _all_stock.index:
        _data[_data['code']==_stock]
# %time f3()
# Out:
# Wall time: 1min 8s

# %%
# 就目前看，2中方法，pandas更胜一筹，只是，也是需要一分多种，太慢了。
