# %%
import tushare_data

# %%
_df=tushare_data.stone.select(tushare_data.str_report,'code="000001" | code="000002"')

# %%
_df
# Out:
#         code  name   eps  eps_yoy  bvps    roe  epcf  net_profits  \
# 341   000002   万科A   NaN      NaN  4.49    NaN -0.48     11458.67
# 852   000001  平安银行   NaN      NaN  1.98    NaN  0.11     17795.28
# 362   000001  平安银行   NaN      NaN  2.44  30.65  0.82     50655.18
# 759   000002   万科A   NaN      NaN  4.61  10.69  0.14     30123.15
# 0     000001  平安银行   NaN      NaN   NaN    NaN   NaN     13882.84
# 466   000002   万科A   NaN      NaN  4.83   5.76 -1.15     17045.95
# 0     000001  平安银行   NaN      NaN   NaN    NaN   NaN     36508.12
# 388   000001  平安银行  0.21      NaN  1.86  10.82  7.52     40236.04
# 1031  000002   万科A   NaN      NaN  4.95  12.21 -1.91     37374.72
# 810   000002   万科A   NaN      NaN  5.00    NaN   NaN      3055.60
# 826   000001  平安银行   NaN      NaN   NaN    NaN   NaN     18395.11
# 370   000002   万科A   NaN      NaN  5.18   4.45 -0.33     14215.69
# 666   000001  平安银行  0.16    39.13  2.03   7.71 -5.33     31414.13
# ...

# %%
# 加上一列，表示季度差值的
_df['_quarter_sub'] = tushare_data.quarter_sub_func(_df['year_quarter'], '2017-4')
_df
# Out:
#         code  name   eps  eps_yoy  bvps    roe  epcf  net_profits  \
# 341   000002   万科A   NaN      NaN  4.49    NaN -0.48     11458.67
# 852   000001  平安银行   NaN      NaN  1.98    NaN  0.11     17795.28
# 362   000001  平安银行   NaN      NaN  2.44  30.65  0.82     50655.18
# 759   000002   万科A   NaN      NaN  4.61  10.69  0.14     30123.15
# 0     000001  平安银行   NaN      NaN   NaN    NaN   NaN     13882.84
# 466   000002   万科A   NaN      NaN  4.83   5.76 -1.15     17045.95
# 0     000001  平安银行   NaN      NaN   NaN    NaN   NaN     36508.12
# 388   000001  平安银行  0.21      NaN  1.86  10.82  7.52     40236.04
# 1031  000002   万科A   NaN      NaN  4.95  12.21 -1.91     37374.72
# 810   000002   万科A   NaN      NaN  5.00    NaN   NaN      3055.60
# 826   000001  平安银行   NaN      NaN   NaN    NaN   NaN     18395.11
# 370   000002   万科A   NaN      NaN  5.18   4.45 -0.33     14215.69
# 666   000001  平安银行  0.16    39.13  2.03   7.71 -5.33     31414.13
# ...

# %%
# 近一年的财报
_df_2 = _df.loc[((_df['_quarter_sub'] < 1) & (_df['_quarter_sub'] > -4))]
_df_2
# Out:
#         code  name   eps  eps_yoy   bvps   roe  epcf  net_profits  \
# 1346  000002   万科A  0.06   -16.00    NaN  0.61   NaN     69541.16
# 2888  000001  平安银行  0.31   -27.91  10.94  2.89 -6.70    621400.00
# 1701  000002   万科A  0.66    36.19  10.20  6.22  1.98    730272.40
# 1791  000002   万科A  0.66    36.19  10.20  6.22  1.98    730272.40
# 3094  000001  平安银行  0.68    -5.56  11.15  6.21 -7.47   1255400.00
# 1851  000002   万科A  1.01    34.36    NaN  9.53   NaN   1109100.09
# 3232  000001  平安银行  1.06    -2.75  11.54  9.60 -9.20   1915300.00
#
#       profits_yoy distrib report_date year_quarter _quarter_sub
# 1346       -16.54     NaN       04-28       2017-1           -3
# 2888         2.10     NaN       04-22       2017-1           -3
# 1701        36.47     NaN       08-25       2017-2           -2
# 1791        36.47     NaN       08-25       2017-2           -2
# 3094         2.13     NaN       08-11       2017-2           -2
# ...

# %%
_group=_df_2.groupby(['code'])
_group

# %%
_group.roe.mean()
# Out:
# code
# 000001    6.233333
# 000002    5.645000
# Name: roe, dtype: float64

# %%
type(_group.roe.mean())
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

# %%
pd.DataFrame(_group.roe.mean())
# Out:
#              roe
# code
# 000001  6.233333
# 000002  5.645000

# %%
_mean=pd.DataFrame(_group.roe.mean())
_mean
# Out:
#              roe
# code
# 000001  6.233333
# 000002  5.645000

# %%
_mean[_mean['roe']>6].index
# Out:
# Index(['000001'], dtype='object', name='code')
