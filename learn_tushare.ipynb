# %%
import tushare as ts

# %%
_profit_data=ts.get_profit_data(2022,1)
# Out:
# [Getting data:]########################################################

# %%
print(_profit_data)
# Out:
#         code   name      roe  net_profit_ratio  gross_profit_rate  \
# 0     600423  *ST柳化   215.12             10.30            -1.3970
# 1     600306    商业城    71.97             71.48            17.3030
# 2     000717   韶钢松山    26.83              3.19             6.2247
# 3     600133   东湖高新    26.81             55.22            11.6396
# 4     002893   华通热力    25.83             21.81            32.2225
# 5     600354   敦煌种业    23.40            302.21            25.0654
# 6     600225  *ST松江    22.84            146.43            24.9719
# 7     600230   沧州大化    21.94             39.66            55.6318
# 8     600338   西藏珠峰    20.28             53.09            70.4140
# 9     000036   华联控股    18.32             42.51            71.4131
# 10    300288   朗玛信息    18.30             85.96            26.9264
# 11    600291   西水股份    17.53             22.32            26.3018
# 12    000505   珠江控股    17.44              5.48            26.3391
# ...

# %%
print(type(_profit_data))
print(_profit_data.keys())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['code', 'name', 'roe', 'net_profit_ratio', 'gross_profit_rate',
#        'net_profits', 'eps', 'business_income', 'bips'],
#       dtype='object')

# %%
help(_profit_data.sort_index)
# Out:
# Help on method sort_index in module pandas.core.frame:
#
# sort_index(axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, by=None) method of pandas.core.frame.DataFrame instance
#     Sort object by labels (along an axis)
#
#     Parameters
#     ----------
#     axis : index, columns to direct sorting
#     level : int or level name or list of ints or list of level names
#         if not None, sort on values in specified index level(s)
#     ascending : boolean, default True
#         Sort ascending vs. descending
#     inplace : bool, default False
#         if True, perform operation in-place
#     kind : {'quicksort', 'mergesort', 'heapsort'}, default 'quicksort'
#          Choice of sorting algorithm. See also ndarray.np.sort for more
#          information.  `mergesort` is the only stable algorithm. For
#          DataFrames, this option is only applied when sorting on a single
#          column or label.
# ...

# %%
help(_profit_data.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last') method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis
#
#     .. versionadded:: 0.17.0
#
#     Parameters
#     ----------
#     by : str or list of str
#         Name or list of names which refer to the axis items.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Axis to direct sorting
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
#          orders.  If this is a list of bools, must match the length of
#          the by.
#     inplace : bool, default False
#          if True, perform operation in-place
#     kind : {'quicksort', 'mergesort', 'heapsort'}, default 'quicksort'
#          Choice of sorting algorithm. See also ndarray.np.sort for more
# ...

# %%
_profit_data.sort_values(by=['eps'],ascending=False)
# Out:
#         code   name      roe  net_profit_ratio  gross_profit_rate  \
# 63    600519   贵州茅台     7.74             46.00            91.1561
# 62    603444    吉比特     7.82             43.55            92.4223
# 11    600291   西水股份    17.53             22.32            26.3018
# 174   300628   亿联网络     5.56             45.10            64.2960
# 36    002304   洋河股份     9.52             36.14            61.2324
# 7     600230   沧州大化    21.94             39.66            55.6318
# 172   601318   中国平安     5.60              8.67            12.2943
# 4     002893   华通热力    25.83             21.81            32.2225
# 268   600694   大商股份     4.59              4.26            22.7553
# 97    000963   华东医药     6.95              7.60            28.1549
# 3     600133   东湖高新    26.81             55.22            11.6396
# 14    600633   浙数文化    16.31            192.98            43.5107
# 1     600306    商业城    71.97             71.48            17.3030
# ...

# %%
_all_stock=ts.get_stock_basics()
print(_all_stock.keys())
# Out:
# Index(['name', 'industry', 'area', 'pe', 'outstanding', 'totals',
#        'totalAssets', 'liquidAssets', 'fixedAssets', 'reserved',
#        'reservedPerShare', 'esp', 'bvps', 'pb', 'timeToMarket', 'undp',
#        'perundp', 'rev', 'profit', 'gpr', 'npr', 'holders'],
#       dtype='object')

# %%
_all_stock.loc[_all_stock['pe']<20]
# Out:
#          name industry area     pe  outstanding  totals   totalAssets  \
# code
# 000801   四川九洲     通信设备   四川   0.00        10.23   10.23  5.086606e+05
# 601828    美凯龙     其他商业   上海  18.54         3.15   39.39  9.579130e+06
# 600908   无锡银行       银行   江苏  17.07         7.92   18.48  1.301790e+07
# 603056   德邦股份     仓储物流   上海  18.68         1.00    9.60  6.081869e+05
# 600506   香梨股份      种植业   新疆   0.00         1.48    1.48  3.043790e+04
# 002180    纳思达     电脑设备   广东   0.00         6.86   10.64  3.585549e+06
# 603323   吴江银行       银行   江苏  16.94         6.07   14.48  8.743300e+06
# 600234   ST山水     文教休闲   山西   0.00         2.02    2.02  4.823264e+04
# 601128   常熟银行       银行   江苏  15.99         9.93   22.23  1.424092e+07
# 600250   南纺股份     商贸代理   江苏   0.00         2.59    2.59  1.680799e+05
# 000622   恒立实业     汽车配件   湖南   0.00         4.25    4.25  4.034848e+04
# 600538   国发股份     农药化肥   广西   0.00         4.64    4.64  9.309596e+04
# ...

# %%
_all_stock.loc[
    (_all_stock['pe']<20)
    &(_all_stock['pe']>0)
    &(_all_stock['pb']<1.5)
    & (_all_stock['name'].str.contains('ST')==False)
    &(_all_stock['area'].str.contains('黑龙江')==False)
     &(_all_stock['area'].str.contains('吉林')==False)
     &(_all_stock['area'].str.contains('辽宁')==False)]
# Out:
#          name industry area     pe  outstanding   totals   totalAssets  \
# code
# 600926   杭州银行       银行   浙江   9.67        14.66    36.64  7.977716e+07
# 600390   五矿资本     多元金融   湖南  15.73         4.51    37.48  1.216213e+07
# 601229   上海银行       银行   上海   8.07        37.07    78.06  1.759999e+08
# 601997   贵阳银行       银行   贵州   8.27        12.09    22.99  4.329321e+07
# 600089   特变电工     电气设备   新疆  15.19        37.14    37.19  8.495627e+06
# 600919   江苏银行       银行   江苏   7.71        59.24   115.44  1.737565e+08
# 601818   光大银行       银行   北京   6.87       398.10   524.89  4.030414e+08
# 601009   南京银行       银行   江苏   7.93        80.70    84.82  1.144671e+08
# 601288   农业银行       银行   北京   6.81      2940.55  3247.94  2.092312e+09
# 600015   华夏银行       银行   北京   6.64       128.23   128.23  2.445789e+08
# 601328   交通银行       银行   上海   6.91       392.51   742.63  8.935791e+08
# 601169   北京银行       银行   北京   7.79       182.48   211.43  2.275226e+08
# ...
