# %%
# %matplotlib inline
# %time from hikyuu.interactive.interactive import *
#use_draw_engine('echarts') #use_draw_engine('matplotlib')  #默认为'matplotlib'绘图
# Out:
# Wall time: 6.1 s

# %%
import datetime
def get_stocks(gt_days):
    _lst=[]
    for _stock in sm:
        if _stock.valid \
        and _stock.type != constant.STOCKTYPE_INDEX  \
        and (datetime.datetime.now()-_stock.startDatetime.datetime()).days>gt_days \
        and 'ST' not in _stock.name :
            _lst.append(_stock)
    return _lst

# %%
print(get_stocks(90))
print(len(get_stocks(90)))
# Out:
# [<Stock(SH, 603600, 永艺股份, A股, 1, 2015-1-23 0:0:0, +infinity)>, <Stock(SH, 501016, 券商基金, 基金（不含ETF）, 1, 2017-5-19 0:0:0, +infinity)>, <Stock(SZ, 002694, 顾地科技, A股, 1, 2012-8-16 0:0:0, +infinity)>, <Stock(SH, 600292, 远达环保, A股, 1, 2000-11-1 0:0:0, +infinity)>, <Stock(SH, 603033, 三维股份, A股, 1, 2016-12-7 0:0:0, +infinity)>, <Stock(SH, 600825, 新华传媒, A股, 1, 1994-2-4 0:0:0, +infinity)>, <Stock(SH, 600388, 龙净环保, A股, 1, 2000-12-29 0:0:0, +infinity)>, <Stock(SZ, 300464, 星徽精密, 创业板, 1, 2015-6-10 0:0:0, +infinity)>, <Stock(SZ, 150328, 新能B级, 基金（不含ETF）, 1, 2015-8-3 0:0:0, +infinity)>, <Stock(SZ, 150272, 生物药B, 基金（不含ETF）, 1, 2015-6-5 0:0:0, +infinity)>, <Stock(SH, 603603, 博天环境, A股, 1, 2017-2-17 0:0:0, +infinity)>, <Stock(SH, 501015, 财通升级, 基金（不含ETF）, 1, 2016-6-6 0:0:0, +infinity)>, <Stock(SZ, 002697, 红旗连锁, A股, 1, 2012-9-5 0:0:0, +infinity)>, <Stock(SH, 603328, 依顿电子, A股, 1, 2014-7-1 0:0:0, +infinity)>, <Stock(SH, 600291, 西水股份, A股, 1, 2000-7-31 0:0:0, +infinity)>, <Stock(SH, 603030, 全筑股份, A股, 1, 2015-3-20 0:0:0, +infinity)>, <Stock(SH, 600826, 兰生股份, A股, 1, 1994-2-4 0:0:0, +infinity)>, <Stock(SZ, 300467, 迅游科技, 创业板, 1, 2015-5-27 0:0:0, +infinity)>, <Stock(SZ, 150271, 生物药A, 基金（不含ETF）, 1, 2015-6-5 0:0:0, +infinity)>, <Stock(SH, 600052, 浙江广厦, A股, 1, 1997-4-15 0:0:0, +infinity)>, <Stock(SZ, 159927, A300ETF, ETF, 1, 2013-8-16 0:0:0, +infinity)>, <Stock(SH, 502037, 网金A, 基金（不含ETF）, 1, 2015-7-7 0:0:0, +infinity)>, <Stock(SH, 600081, 东风科技, A股, 1, 1997-7-3 0:0:0, +infinity)>, <Stock(SZ, 159916, 深F60, ETF, 1, 2011-10-24 0:0:0, +infinity)>, <Stock(SH, 601011, 宝泰隆, A股, 1, 2011-3-9 0:0:0, +infinity)>, <Stock(SH, 502006, 国企改革, 基金（不含ETF）, 1, 2015-6-25 0:0:0, +infinity)>, <Stock(SH, 501021, 香港中小, 基金（不含ETF）, 1, 2016-7-6 0:0:0, +infinity)>, <Stock(SZ, 300413, 快乐购, 创业板, 1, 2015-1-21 0:0:0, +infinity)>, <Stock(SH, 600179, 安通控股, A股, 1, 1998-11-4 0:0:0, +infinity)>, <Stock(SZ, 002696, 百洋股份, A股, 1, 2012-9-5 0:0:0, +infinity)>, <Stock(SH, 600290, 华仪电气, A股, 1, 2000-11-6 0:0:0, +infinity)>, <Stock(SH, 603031, 安德利, A股, 1, 2016-8-22 0:0:0, +infinity)>, <Stock(SH, 600827, 百联股份, A股, 1, 1994-2-4 0:0:0, +infinity)>, <Stock(SZ, 300466, 赛摩电气, 创业板, 1, 2015-5-28 0:0:0, +infinity)>, <Stock(SZ, 150270, 白酒B, 基金（不含ETF）, 1, 2015-6-5 0:0:0, +infinity)>, <Stock(SZ, 159910, 深F120, ETF, 1, 2011-9-27 0:0:0, +infinity)>, <Stock(SH, 502000, 500等权, 基金（不含ETF）, 1, 2015-4-27 0:0:0, +infinity)>, <Stock(SH, 501027, 国泰融信, 基金（不含ETF）, 1, 2017-6-1 0:0:0, +infinity)>, <Stock(SZ, 300415, 伊之密, 创业板, 1, 2015-1-23 0:0:0, +infinity)>, <Stock(SZ, 002691, 冀凯股份, A股, 1, 2012-7-31 0:0:0, +infinity)>, <Stock(SH, 600297, 广汇汽车, A股, 1, 2000-11-16 0:0:0, +infinity)>, <Stock(SH, 603036, 如通股份, A股, 1, 2016-12-9 0:0:0, +infinity)>, <Stock(SH, 600820, 隧道股份, A股, 1, 1994-1-28 0:0:0, +infinity)>, <Stock(SZ, 300461, 田中精机, 创业板, 1, 2015-5-19 0:0:0, +infinity)>, <Stock(SZ, 150277, 高铁A, 基金（不含ETF）, 1, 2015-6-5 0:0:0, +infinity)>, <Stock(SH, 600086, 东方金钰, A股, 1, 1997-6-6 0:0:0, +infinity)>, <Stock(SZ, 000811, 冰轮环境, A股, 1, 1998-5-28 0:0:0, +infinity)>, <Stock(SH, 512400, 有色金属, ETF, 1, 2017-9-1 0:0:0, +infinity)>, <Stock(SZ, 159911, 民营ETF, ETF, 1, 2011-10-14 0:0:0, +infinity)>, <Stock(SH, 601016, 节能风电, A股, 1, 2014-9-29 0:0:0, +infinity)>, <Stock(SH, 502001, 500等权A, 基金（不含ETF）, 1, 2015-4-27 0:0:0, +infinity)>, <Stock(SH, 501026, 财通福享, 基金（不含ETF）, 1, 2016-12-15 0:0:0, +infinity)>, <Stock(SZ, 300414, 中光防雷, 创业板, 1, 2015-5-13 0:0:0, +infinity)>, <Stock(SZ, 002152, 广电运通, A股, 1, 2007-8-13 0:0:0, +infinity)>, <Stock(SH, 600077, 宋都股份, A股, 1, 1997-5-20 0:0:0, +infinity)>, <Stock(SH, 603612, 索通发展, A股, 1, 2017-7-18 0:0:0, +infinity)>, <Stock(SH, 501000, 国金鑫新, 基金（不含ETF）, 1, 2015-7-14 0:0:0, +infinity)>, <Stock(SZ, 000722, 湖南发展, A股, 1, 1997-5-22 0:0:0, +infinity)>, <Stock(SH, 603855, 华荣股份, A股, 1, 2017-5-24 0:0:0, +infinity)>, <Stock(SZ, 002153, 石基信息, A股, 1, 2007-8-13 0:0:0, +infinity)>, <Stock(SH, 600076, 康欣新材, A股, 1, 1997-5-26 0:0:0, +infinity)>, <Stock(SH, 501001, 财通精选, 基金（不含ETF）, 1, 2015-9-25 0:0:0, +infinity)>, <Stock(SZ, 002150, 通润装备, A股, 1, 2007-8-10 0: ...
# 4143
