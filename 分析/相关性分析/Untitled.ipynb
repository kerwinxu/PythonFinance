# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
# matplotlib.use('agg')
import matplotlib.pyplot as plt
import os
# from tqdm.notebook import  tqdm
from tqdm import  tqdm
import talib
import datetime
import math
import  mplfinance as mpf

import sys
sys.path.append('../../DataSource/聚宽数据')
import datasource 
sys.path.append('../..')
import Utils
# 这个是筛选多少天上涨多少的，
codes = datasource.getAStockCodes()
print(f'股票数量:{len(codes)},第一支股票:{codes[0]}')
code = codes[0]
dt = datasource.getData(code)
dt.head()
# Out:
# 股票数量:4897,第一支股票:000001.XSHE
#                         index  open  high   low  close         money  \
# code        date
# 000001.XSHE 2018-03-15      0  9.02  9.07  8.92   8.96  1.356879e+09
#             2018-03-16      1  8.97  9.07  8.91   8.91  1.130784e+09
#             2018-03-19      2  8.92  9.06  8.89   9.06  9.476647e+08
#             2018-03-20      3  8.99  9.09  8.97   9.05  9.168585e+08
#             2018-03-21      4  9.15  9.28  9.07   9.11  1.736437e+09
#
#                              volume
# code        date
# 000001.XSHE 2018-03-15  150985124.0
#             2018-03-16  125808452.0
#             2018-03-19  105631111.0
#             2018-03-20  101399707.0
#             2018-03-21  188795564.0
