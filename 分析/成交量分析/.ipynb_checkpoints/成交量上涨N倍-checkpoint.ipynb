# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
# matplotlib.use('agg')
# matplotlib.use('TkAgg')

import matplotlib.pyplot as plt
import os
# from tqdm.notebook import  tqdm
from tqdm import  tqdm
import talib
import datetime

import  mplfinance as mpf

import sys
sys.path.append('../../DataSource/baostock')
import datasource

# %%
# 这个是看rsi大于80的情况下，涨跌幅的
codes = datasource.get_codes()
code = codes[0]
dt = datasource.get_data(code)
dt.head()
# Out:
#                  code      open      high       low     close  preclose  \
# date
# 2010-01-04  sh.600000  5.079055  5.088362  4.923170  4.930150  5.046482
# 2010-01-05  sh.600000  4.981336  5.020889  4.837085  4.967376  4.930150
# 2010-01-06  sh.600000  4.953417  4.955743  4.858024  4.869658  4.967376
# 2010-01-07  sh.600000  4.858024  4.895251  4.723079  4.760305  4.869658
# 2010-01-08  sh.600000  4.732386  4.839411  4.723079  4.813818  4.760305
#
#                volume        amount  adjustflag      turn  tradestatus  \
# date
# 2010-01-04   66191338  1.419984e+09           2  0.835129            1
# 2010-01-05  115147943  2.436891e+09           2  1.452808            1
# 2010-01-06   96782575  2.034174e+09           2  1.221095            1
# 2010-01-07   85236072  1.761801e+09           2  1.075414            1
# 2010-01-08   65707646  1.349532e+09           2  0.829026            1
#
#             pctChg  isST
# date
# 2010-01-04 -2.3052     0
# 2010-01-05  0.7551     0
# 2010-01-06 -1.9672     0
# 2010-01-07 -2.2456     0
# 2010-01-08  1.1241     0

# %%
# 这里volume上涨多少倍
N1 = 1.02
N2 = 2

dt['prevolume'] = dt['volume'].shift(1)
for i in range(5):
    dt[f'close{i+1}'] = dt['close'].shift(-(i+1))
    dt[f'rate{i+1}'] = (dt[f'close{i+1}']-dt['close'])/dt['close']*100
dt2 = dt.loc[(dt['close'] > N1 *  dt['preclose']) & (dt['prevolume'] > N2 * dt['volume']) ]
dt2.head()
# Out:
# Empty DataFrame
# Columns: [code, open, high, low, close, preclose, volume, amount, adjustflag, turn, tradestatus, pctChg, isST, prevolume, close1, rate1, close2, rate2, close3, rate3, close4, rate4, close5, rate5]
# Index: []
#
# [0 rows x 24 columns]
